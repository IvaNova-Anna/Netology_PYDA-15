# %% [markdown]
# ## Домашнее задание «Функции и работа с данными»

# %% [markdown]
# ### Задание 1
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# - оценка 2 и меньше - низкий рейтинг
# - оценка 4 и меньше - средний рейтинг
# - оценка 4.5 и 5 - высокий рейтинг
#
# Результат классификации запишите в столбец class

# %%
import pandas as pd
movies_rt = pd.read_csv('ratings.csv')
def rating_level(row):
    rt_class = ''
    if row  <= 2:
        rt_class = 'низкий рейтинг'
    if row  > 2 and row <= 4:
        rt_class = 'средний рейтинг'
    if row  > 4 and row <= 5:
        rt_class = 'высокий рейтинг'
    return rt_class
movies_rt['class'] = movies_rt['rating'].apply(rating_level)
movies_rt.loc[0:100]
# Out:
#      userId  movieId  rating   timestamp            class
# 0         1       31     2.5  1260759144  средний рейтинг
# 1         1     1029     3.0  1260759179  средний рейтинг
# 2         1     1061     3.0  1260759182  средний рейтинг
# 3         1     1129     2.0  1260759185   низкий рейтинг
# 4         1     1172     4.0  1260759205  средний рейтинг
# ..      ...      ...     ...         ...              ...
# 96        3       60     3.0  1298861675  средний рейтинг
# 97        3      110     4.0  1298922049  средний рейтинг
# 98        3      247     3.5  1298861637  средний рейтинг
# 99        3      267     3.0  1298861761  средний рейтинг
# 100       3      296     4.5  1298862418  высокий рейтинг
#
# [101 rows x 5 columns]

# %% [markdown]
# ### Задание 2
# Используем файл keywords.csv.
#
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# geo_data = {
#
# 'Центр': ['москва', 'тула', 'ярославль'],
#
# 'Северо-Запад': ['петербург', 'псков', 'мурманск'],
#
# 'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск'] }
#
# Результат классификации запишите в отдельный столбец region.

# %%
geo_data = {

'Центр': ['москва', 'тула', 'ярославль'],

'Северо-Запад': ['петербург', 'псков', 'мурманск'],

'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск'] }
keywords = pd.read_csv('keywords.csv')
def region_definer(row):
    region = ''
    for region_list in geo_data.items():
        for city in region_list[1]:
            if city in row :
                region = region_list[0]
    if not region:
        region = 'undefined'
    return region
keywords['region'] = keywords.keyword.apply(region_definer)
print (keywords.groupby('region').count().head())
keywords.loc[0:150]
# Out:
#                 keyword  shows
# region
# undefined         99253  99253
# Дальний Восток       94     94
# Северо-Запад        268    268
# Центр               385    385
#                                                keyword     shows     region
# 0                                                   вк  64292779  undefined
# 1                                        одноклассники  63810309  undefined
# 2                                                порно  41747114  undefined
# 3                                                 ютуб  39995567  undefined
# 4                                            вконтакте  21014195  undefined
# ..                                                 ...       ...        ...
# 146                                         зайцев нет    878182  undefined
# 147  кино онлайн 2016 бесплатно в хорошем качестве ...    884774  undefined
# 148                 гдз по математике 6 класс виленкин    867318  undefined
# 149                                            xvideos    866561  undefined
# 150                              билайн личный кабинет   1238073  undefined
#
# [151 rows x 3 columns]
