# %% [markdown]
# # Настройка среды и работа с Git
#
# ## Anna Ivanova

# %% [markdown]
# ### Задание 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Задание 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Задание 3

# %% [markdown]
# https://github.com/IvaNova-Anna/Netology_PYDA-15
